# %%
import pandas as pd

# %%
# df = pd.read_parquet('_6bNvy6IFAs.parquet')
df = pd.read_parquet('_0N5vnNM2AA_0_7.parquet')
print(df)
# Out:
#        video_id video_number  frame_number desync  feature_0  feature_1  \
# 0   _0N5vnNM2AA            0             0      7  -0.008057  -0.216847
# 1   _0N5vnNM2AA            0             1      7  -0.050876  -0.200507
# 2   _0N5vnNM2AA            0             2      7  -0.056273  -0.203734
# 3   _0N5vnNM2AA            0             3      7  -0.097816  -0.191825
# 4   _0N5vnNM2AA            0             4      7  -0.085986  -0.125138
# ..          ...          ...           ...    ...        ...        ...
# 71  _0N5vnNM2AA            0            71      7  -0.205075  -0.075567
# 72  _0N5vnNM2AA            0            72      7  -0.210299  -0.076489
# 73  _0N5vnNM2AA            0            73      7  -0.213342  -0.109870
# 74  _0N5vnNM2AA            0            74      7  -0.163660  -0.105794
# 75  _0N5vnNM2AA            0            75      7  -0.215903  -0.073606
#
#     feature_2  feature_3  feature_4  feature_5  ...  feature_1270  \
# ...
