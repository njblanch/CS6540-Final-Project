# %%
import pandas as pd

# %%
df = pd.read_parquet('_6bNvy6IFAs.parquet')
print(df)
# Out:
#         video_id video_number  frame_number desync  feature_0  feature_1  \
# 0    _6bNvy6IFAs            9             0     14   0.021975  -0.027735
# 1    _6bNvy6IFAs            9             1     14   0.026022  -0.032406
# 2    _6bNvy6IFAs            9             2     14   0.033137  -0.030223
# 3    _6bNvy6IFAs            9             3     14   0.030875  -0.037013
# 4    _6bNvy6IFAs            9             4     14   0.033185  -0.024144
# ..           ...          ...           ...    ...        ...        ...
# 493  _6bNvy6IFAs            4            82     -1   0.106111  -0.053808
# 494  _6bNvy6IFAs            4            83     -1   0.089216  -0.047515
# 495  _6bNvy6IFAs            4            84     -1   0.085518  -0.075556
# 496  _6bNvy6IFAs            4            85     -1   0.098185  -0.079593
# 497  _6bNvy6IFAs            4            86     -1   0.063369  -0.077304
#
#      feature_2  feature_3  feature_4  feature_5  ...  feature_118  \
# ...
